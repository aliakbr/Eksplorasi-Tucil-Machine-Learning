# %% [markdown]
# ## Eksplorasi Machine Learning : Python Scikitlearn

# %% [markdown]
# ### Anggota
# 13514080 Ali Akbar
#
# 13514086 Azka Hanif
#
# 13514092 Muhammad Gumilang
#
# Pada eksplorasi ini kami akan menuliskan catatan untuk tiap poin pengerjaan

# %% [markdown]
# ### Poin a Pembacaan Dataset
#
# Pada poin ini kami akan membaca dataset menggunakan modul pandas read_csv. Agar read_csv tidak menghasilkan error, file 'iris.csv' dan 'playtennis.csv' harus berada pada direktori yang sama

# %% [markdown]
# Berikut adalah data dari Iris CSV

# %%
import pandas as pd
import numpy as np
pd1 = pd.read_csv('iris.csv')
print(pd1)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# 7            5.0         3.4          1.5         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 11           4.8         3.4          1.6         0.2     Iris-setosa
# 12           4.8         3.0          1.4         0.1     Iris-setosa
# 13           4.3         3.0          1.1         0.1     Iris-setosa
# 14           5.8         4.0          1.2         0.2     Iris-setosa
# 15           5.7         4.4          1.5         0.4     Iris-setosa
# 16           5.4         3.9          1.3         0.4     Iris-setosa
# 17           5.1         3.5          1.4         0.3     Iris-setosa
# 18           5.7         3.8          1.7         0.3     Iris-setosa
# 19           5.1         3.8          1.5         0.3     Iris-setosa
# 20           5.4         3.4          1.7         0.2     Iris-setosa
# 21           5.1         3.7          1.5         0.4     Iris-setosa
# 22           4.6         3.6          1.0         0.2     Iris-setosa
# 23           5.1         3.3          1.7         0.5     Iris-setosa
# 24           4.8         3.4          1.9         0.2     Iris-setosa
# 25           5.0         3.0          1.6         0.2     Iris-setosa
# 26           5.0         3.4          1.6         0.4     Iris-setosa
# 27           5.2         3.5          1.5         0.2     Iris-setosa
# 28           5.2         3.4          1.4         0.2     Iris-setosa
# 29           4.7         3.2          1.6         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 120          6.9         3.2          5.7         2.3  Iris-virginica
# 121          5.6         2.8          4.9         2.0  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 123          6.3         2.7          4.9         1.8  Iris-virginica
# 124          6.7         3.3          5.7         2.1  Iris-virginica
# 125          7.2         3.2          6.0         1.8  Iris-virginica
# 126          6.2         2.8          4.8         1.8  Iris-virginica
# 127          6.1         3.0          4.9         1.8  Iris-virginica
# 128          6.4         2.8          5.6         2.1  Iris-virginica
# 129          7.2         3.0          5.8         1.6  Iris-virginica
# 130          7.4         2.8          6.1         1.9  Iris-virginica
# 131          7.9         3.8          6.4         2.0  Iris-virginica
# 132          6.4         2.8          5.6         2.2  Iris-virginica
# 133          6.3         2.8          5.1         1.5  Iris-virginica
# 134          6.1         2.6          5.6         1.4  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica
# 136          6.3         3.4          5.6         2.4  Iris-virginica
# 137          6.4         3.1          5.5         1.8  Iris-virginica
# 138          6.0         3.0          4.8         1.8  Iris-virginica
# 139          6.9         3.1          5.4         2.1  Iris-virginica
# 140          6.7         3.1          5.6         2.4  Iris-virginica
# 141          6.9         3.1          5.1         2.3  Iris-virginica
# 142          5.8         2.7          5.1         1.9  Iris-virginica
# 143          6.8         3.2          5.9         2.3  Iris-virginica
# 144          6.7         3.3          5.7         2.5  Iris-virginica
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Dan berikut adalah data dari playtennis

# %%
pd2 = pd.read_csv('playtennis.csv')
print(pd2)
# Out:
#      outlook temperature humidity    wind playtennis
# 0      sunny         hot     high    weak         no
# 1      sunny         hot     high  strong         no
# 2   overcast         hot     high    weak        yes
# 3       rain        mild     high    weak        yes
# 4       rain        cool   normal    weak        yes
# 5       rain        cool   normal  strong         no
# 6   overcast        cool   normal  strong        yes
# 7      sunny        mild     high    weak         no
# 8      sunny        cool   normal    weak        yes
# 9       rain        mild   normal    weak        yes
# 10     sunny        mild   normal  strong        yes
# 11  overcast        mild     high  strong        yes
# 12  overcast         hot   normal    weak        yes
# 13      rain        mild     high  strong         no

# %%
Xiris = pd1.iloc[:,0:4].values.tolist()
print(Xiris)
Yiris = pd1.iloc[:,-1].values.tolist()
print(Yiris)
# Out:
# [[5.1, 3.5, 1.4, 0.2], [4.9, 3.0, 1.4, 0.2], [4.7, 3.2, 1.3, 0.2], [4.6, 3.1, 1.5, 0.2], [5.0, 3.6, 1.4, 0.2], [5.4, 3.9, 1.7, 0.4], [4.6, 3.4, 1.4, 0.3], [5.0, 3.4, 1.5, 0.2], [4.4, 2.9, 1.4, 0.2], [4.9, 3.1, 1.5, 0.1], [5.4, 3.7, 1.5, 0.2], [4.8, 3.4, 1.6, 0.2], [4.8, 3.0, 1.4, 0.1], [4.3, 3.0, 1.1, 0.1], [5.8, 4.0, 1.2, 0.2], [5.7, 4.4, 1.5, 0.4], [5.4, 3.9, 1.3, 0.4], [5.1, 3.5, 1.4, 0.3], [5.7, 3.8, 1.7, 0.3], [5.1, 3.8, 1.5, 0.3], [5.4, 3.4, 1.7, 0.2], [5.1, 3.7, 1.5, 0.4], [4.6, 3.6, 1.0, 0.2], [5.1, 3.3, 1.7, 0.5], [4.8, 3.4, 1.9, 0.2], [5.0, 3.0, 1.6, 0.2], [5.0, 3.4, 1.6, 0.4], [5.2, 3.5, 1.5, 0.2], [5.2, 3.4, 1.4, 0.2], [4.7, 3.2, 1.6, 0.2], [4.8, 3.1, 1.6, 0.2], [5.4, 3.4, 1.5, 0.4], [5.2, 4.1, 1.5, 0.1], [5.5, 4.2, 1.4, 0.2], [4.9, 3.1, 1.5, 0.1], [5.0, 3.2, 1.2, 0.2], [5.5, 3.5, 1.3, 0.2], [4.9, 3.1, 1.5, 0.1], [4.4, 3.0, 1.3, 0.2], [5.1, 3.4, 1.5
 2.0], [5.8, 2.8, 5.1, 2.4], [6.4, 3.2, 5.3, 2.3], [6.5, 3.0, 5.5, 1.8], [7.7, 3.8, 6.7, 2.2], [7.7, 2.6, 6.9, 2.3], [6.0, 2.2, 5.0, 1.5], [6.9, 3.2, 5.7, 2.3], [5.6, 2.8, 4.9, 2.0], [7.7, 2.8, 6.7, 2.0], [6.3, 2.7, 4.9, 1.8], [6.7, 3.3, 5.7, 2.1], [7.2, 3.2, 6.0, 1.8], [6.2, 2.8, 4.8, 1.8], [6.1, 3.0, 4.9, 1.8], [6.4, 2.8, 5.6, 2.1], [7.2, 3.0, 5.8, 1.6], [7.4, 2.8, 6.1, 1.9], [7.9, 3.8, 6.4, 2.0], [6.4, 2.8, 5.6, 2.2], [6.3, 2.8, 5.1, 1.5], [6.1, 2.6, 5.6, 1.4], [7.7, 3.0, 6.1, 2.3], [6.3, 3.4, 5.6, 2.4], [6.4, 3.1, 5.5, 1.8], [6.0, 3.0, 4.8, 1.8], [6.9, 3.1, 5.4, 2.1], [6.7, 3.1, 5.6, 2.4], [6.9, 3.1, 5.1, 2.3], [5.8, 2.7, 5.1, 1.9], [6.8, 3.2, 5.9, 2.3], [6.7, 3.3, 5.7, 2.5], [6.7, 3.0, 5.2, 2.3], [6.3, 2.5, 5.0, 1.9], [6.5, 3.0, 5.2, 2.0], [6.2, 3.4, 5.4, 2.3], [5.9, 3.0, 5.1, 1.8]]
# ['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica']

# %% [markdown]
# ## Poin b : Melakukan Pembelajaran dengan DTL dan MLP

# %%
# Full-training DTL
from sklearn import tree

clf1 = tree.DecisionTreeClassifier()
clf1 = clf1.fit(Xiris,Yiris)

# %%
# Visualisasi DTL
import graphviz

dot_data = tree.export_graphviz(clf1, out_file=None)
graph = graphviz.Source(dot_data)
graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\graphviz\backend.py in pipe(engine, format, data, quiet)
#     153             stdout=subprocess.PIPE, stderr=subprocess.PIPE,
# --> 154             startupinfo=STARTUPINFO)
#     155     except OSError as e:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#     989                                          cwd,
# --> 990                                          startupinfo)
#     991             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\graphviz\files.py in _repr_svg_(self)
#     103
#     104     def _repr_svg_(self):
# --> 105         return self.pipe(format='svg').decode(self._encoding)
#     106
#     107     def pipe(self, format=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\graphviz\files.py in pipe(self, format)
#     122         data = text_type(self.source).encode(self._encoding)
#     123
# --> 124         outs = backend.pipe(self._engine, format, data)
#     125
#     126         return outs
#
# C:\ProgramData\Anaconda3\lib\site-packages\graphviz\backend.py in pipe(engine, format, data, quiet)
#     155     except OSError as e:
#     156         if e.errno == errno.ENOENT:
# --> 157             raise ExecutableNotFound(args)
#     158         else:  # pragma: no cover
#     159             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tsvg'], make sure the Graphviz executables are on your systems' PATH

# %%
#Full-training MLP
from sklearn.neural_network import MLPClassifier
clf2 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(15, 3), random_state=1)
clf2.fit(Xiris, Yiris)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(15, 3), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
#Visualisasi MLP
import matplotlib.pyplot as plt

fig, axes = plt.subplots(4,4)
vmin, vmax = clf2.coefs_[0].min(), clf2.coefs_[0].max()
for coef, ax in zip(clf2.coefs_[0].T, axes.ravel()):
    ax.matshow(coef.reshape(1,4), cmap=plt.cm.gray, vmin=.5 * vmin, vmax=.5 * vmax)
    ax.set_xticks(())
    ax.set_yticks(())
    
plt.show()

# %% [markdown]
# ## Poin c : Pembelajaran dengan Split Test, 90% untuk Train dan 10% untuk tes

# %%
#Split data 90%/10%
from sklearn.model_selection import train_test_split, KFold, cross_val_score

X_train, X_test, Y_train, Y_test = train_test_split(Xiris, Yiris, test_size=0.1, random_state=42)
print(X_train)
print(X_test)
# Out:
# [[6.3, 3.3, 4.7, 1.6], [6.5, 3.0, 5.8, 2.2], [5.6, 2.5, 3.9, 1.1], [5.7, 2.8, 4.5, 1.3], [6.4, 2.8, 5.6, 2.2], [4.7, 3.2, 1.6, 0.2], [6.1, 3.0, 4.9, 1.8], [5.0, 3.4, 1.6, 0.4], [6.4, 2.8, 5.6, 2.1], [7.9, 3.8, 6.4, 2.0], [6.7, 3.0, 5.2, 2.3], [6.7, 2.5, 5.8, 1.8], [6.8, 3.2, 5.9, 2.3], [4.8, 3.0, 1.4, 0.3], [4.8, 3.1, 1.6, 0.2], [4.6, 3.6, 1.0, 0.2], [5.7, 4.4, 1.5, 0.4], [6.7, 3.1, 4.4, 1.4], [4.8, 3.4, 1.6, 0.2], [4.4, 3.2, 1.3, 0.2], [6.3, 2.5, 5.0, 1.9], [6.4, 3.2, 4.5, 1.5], [5.2, 3.5, 1.5, 0.2], [5.0, 3.6, 1.4, 0.2], [5.2, 4.1, 1.5, 0.1], [5.8, 2.7, 5.1, 1.9], [6.0, 3.4, 4.5, 1.6], [6.7, 3.1, 4.7, 1.5], [5.4, 3.9, 1.3, 0.4], [5.4, 3.7, 1.5, 0.2], [5.5, 2.4, 3.7, 1.0], [6.3, 2.8, 5.1, 1.5], [6.4, 3.1, 5.5, 1.8], [6.6, 3.0, 4.4, 1.4], [7.2, 3.6, 6.1, 2.5], [5.7, 2.9, 4.2, 1.3], [7.6, 3.0, 6.6, 2.1], [5.6, 3.0, 4.5, 1.5], [5.1, 3.5, 1.4, 0.2], [7.7, 2.8, 6.7, 2.0], [5.8, 2.7, 4.1, 1.0], [5.2, 3.4, 1.4, 0.2], [5.0, 3.5, 1.3, 0.3], [5.1, 3.8, 1.9, 0.4], [5.0, 2.0, 3.5, 1.0], [6.3, 2.7, 4.9, 1.8], [4.8, 3.4, 1.9, 0.2], [5.0, 3.0, 1.6, 0.2], [5.1, 3.3, 1.7, 
.8], [5.7, 2.8, 4.1, 1.3], [6.5, 3.0, 5.5, 1.8], [6.3, 2.3, 4.4, 1.3], [6.4, 2.9, 4.3, 1.3], [5.6, 2.8, 4.9, 2.0], [5.9, 3.0, 5.1, 1.8], [5.4, 3.4, 1.7, 0.2], [6.1, 2.8, 4.0, 1.3], [4.9, 2.5, 4.5, 1.7], [5.8, 4.0, 1.2, 0.2], [5.8, 2.6, 4.0, 1.2], [7.1, 3.0, 5.9, 2.1]]
# [[6.1, 2.8, 4.7, 1.2], [5.7, 3.8, 1.7, 0.3], [7.7, 2.6, 6.9, 2.3], [6.0, 2.9, 4.5, 1.5], [6.8, 2.8, 4.8, 1.4], [5.4, 3.4, 1.5, 0.4], [5.6, 2.9, 3.6, 1.3], [6.9, 3.1, 5.1, 2.3], [6.2, 2.2, 4.5, 1.5], [5.8, 2.7, 3.9, 1.2], [6.5, 3.2, 5.1, 2.0], [4.8, 3.0, 1.4, 0.1], [5.5, 3.5, 1.3, 0.2], [4.9, 3.1, 1.5, 0.1], [5.1, 3.8, 1.5, 0.3]]

# %%
# Split data training DTL
clf3 = tree.DecisionTreeClassifier()
clf3 = clf3.fit(X_train,Y_train)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
# Kinerja DTL
# Akurasi
y_pred = clf3.predict(X_test)
print('Akurasi =', accuracy_score(Y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(Y_test, y_pred)
print('Confusion Matrix =\n', cm)
# Out:
# Akurasi = 1.0
# Confusion Matrix =
#  [[6 0 0]
#  [0 6 0]
#  [0 0 3]]

# %%
# Split data training MLP
clf4 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(15, 3), random_state=1)
clf4.fit(X_train, Y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(15, 3), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
# Kinerja MLP
# Akurasi
y_pred = clf4.predict(X_test)
print('Akurasi =', accuracy_score(Y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(Y_test, y_pred)
print('Confusion Matrix =\n', cm)
# Out:
# Akurasi = 0.2
# Confusion Matrix =
#  [[0 0 6]
#  [0 0 6]
#  [0 0 3]]

# %% [markdown]
# ## Poin d : Pembelajaran untuk 10-Fold Cross Validation

# %%
#Cross validation training DTL
clf5 = tree.DecisionTreeClassifier()
scores = cross_val_score(clf5, Xiris, Yiris, cv=10)
print('Akurasi/fold =', scores)
print("Akurasi: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Akurasi/fold = [ 1.          0.93333333  1.          0.93333333  0.93333333  0.86666667
#   0.93333333  0.93333333  1.          1.        ]
# Akurasi: 0.95 (+/- 0.09)

# %%
#Cross validation training MLP
clf6 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(15, 3), random_state=1)
scores = cross_val_score(clf6, Xiris, Yiris, cv=10)
print('Akurasi/fold =', scores)
print("Akurasi: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Akurasi/fold = [ 0.33333333  0.33333333  0.33333333  0.33333333  0.33333333  0.33333333
#   0.33333333  0.33333333  0.33333333  0.33333333]
# Akurasi: 0.33 (+/- 0.00)

# %% [markdown]
# ## Poin e : Menyimpan model/hipotesis ke file eksternal
#
# Untuk penyimpanan model ke file eksternal akan digunakan library pada sklearn yaitu joblib. Joblib merupakan modul yang sudah ada dalam sklearn untuk digunakan dalam penyimpanan model, joblib ini pada umumnya lebih efisien untuk digunakan pada model yang menyimpan array numpy yang besar daripada Pickle yang merupakan modul bawaan python dengan fungsi serupa. Pada eksplorasi ini, setiap training yang dilakukan akan disimpan pada model file eksternal masing-masing.

# %%
from sklearn.externals import joblib

joblib.dump(clf1, 'full_train_dtl.pkl')
joblib.dump(clf2, 'full_train_mlp.pkl')
joblib.dump(clf3, 'split_train_dtl.pkl')
joblib.dump(clf4, 'split_train_mlp.pkl')
# Out:
# ['split_train_mlp.pkl']

# %% [markdown]
# ## Poin f : Membaca model/hipotesis dari file eksternal
#
# Serupa dengan poin e, kami akan menggunakan joblib untuk membaca model dari file eksternal.

# %%
clf7 = joblib.load('full_train_dtl.pkl')
clf8 = joblib.load('full_train_mlp.pkl')
clf9 = joblib.load('split_train_dtl.pkl')
clf10 = joblib.load('split_train_mlp.pkl')

# %% [markdown]
# ## Poin g : Membuat instance baru
#
# Untuk pembuatan instance baru, maka setiap atribut dari instance akan diisi dengan nilai dari input user.

# %%
instance = []
i = 1
for attr in Xiris[0]:
    in_user = input('Masukan nilai atribut ke-' + str(i) + ' ')
    instance.append(float(in_user))
    i = i + 1
    
print()
print('Instance input:')
print(instance)
# Out:
# Masukan nilai atribut ke-1 6
# Masukan nilai atribut ke-2 5
# Masukan nilai atribut ke-3 4
# Masukan nilai atribut ke-4 1
#
# Instance input:
# [6.0, 5.0, 4.0, 1.0]

# %% [markdown]
# ## Poin h : Klasifikasi instance baru
#
# Klasifikasi akan kami lakukan dengan menggunakan classifier yang telah di load sebelumnya pada poin f.

# %%
classify_instance = [instance]

print('Hasil klasifikasi dari full train DTL')
print(clf7.predict(classify_instance))
print('Hasil klasifikasi dari full train MLP')
print(clf8.predict(classify_instance))
print('Hasil klasifikasi dari split train DTL')
print(clf9.predict(classify_instance))
print('Hasil klasifikasi dari split train MLP')
print(clf10.predict(classify_instance))
# Out:
# Hasil klasifikasi dari full train DTL
# ['Iris-versicolor']
# Hasil klasifikasi dari full train MLP
# ['Iris-virginica']
# Hasil klasifikasi dari split train DTL
# ['Iris-versicolor']
# Hasil klasifikasi dari split train MLP
# ['Iris-virginica']

# %% [markdown]
# ## Poin i : Hubungan antar FeatureVisualisasi  Dengan Seaborn
#
# Seaborn adalah modul visualisasi dari python yang memanfaatkan matplotlib. Pada eksplorasi ini akan ditampilkan hubungan antar feature terhadap kelas pada dataset.

# %%
import seaborn as sns
graph = sns.pairplot(pd1, hue='class', kind="reg")
plt.show()

# %% [markdown]
# Dari visualisasi di atas dapat kita lihat untuk tiap kelas hubungan antar data sangat berbeda terhadap setiap kelas. Apabila antara garis aproksimasi regresi menunjukkan adanya kemonotonan (seperti sepallength dan sepalwidth pada kelas Iris-Setosa) maka kedua feature berkorelasi terhadap kelas. Sementara jika tidak ada kemonotonan (seperti sepalwidth dan petalwidth pada kelas Iris-Setosa) maka kedua feature tidak berkorelasi pada kelas tersebut.
